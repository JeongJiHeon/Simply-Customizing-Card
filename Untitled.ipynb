# %%
ls
# Out:
# All-Age-Faces Dataset/ StyleGAN/              __pycache__/
# KBAIproject/           U_GAT_IT/              main.ipynb
# README.md              Untitled.ipynb         requirements.txt

# %%
import glob

# %%
A = glob.glob('/Users/jeongjiheon/Desktop/github/Simply-Customizing-Card/All-Age-Faces Dataset/aglined faces/*.jpg')

# %%
len(A)
# Out:
# 13322

# %%
from PIL import Image

# %%
import random

# %%
B = []
while True:
    if len(B) == 3500:
        break
    rand = random.randint(0, 13322)
    if not rand in B:
        B.append(rand)

# %%
pwd
# Out:
# '/Users/jeongjiheon/Desktop/github/Simply-Customizing-Card'

# %%
for i,b in enumerate(B):
    Image.open(A[b]).resize([512, 512]).save('/Users/jeongjiheon/Desktop/github/Simply-Customizing-Card/faceData/{:05}.jpg'.format(i))

# %%
B.sort()

# %%
B
# Out:
# [0,
#  9,
#  19,
#  22,
#  23,
#  37,
#  42,
#  53,
#  56,
#  57,
#  59,
#  66,
#  67,
#  80,
#  81,
#  82,
#  85,
#  86,
#  88,
#  89,
#  93,
#  98,
#  99,
#  100,
#  102,
#  104,
#  107,
#  121,
#  124,
#  132,
#  133,
#  134,
#  135,
#  138,
#  153,
#  160,
#  168,
#  170,
#  177,
#  178,
#  181,
#  184,
#  185,
#  190,
#  191,
#  198,
#  205,
#  206,
#  210,
#  211,
#  212,
#  218,
#  220,
#  238,
#  247,
#  251,
#  252,
#  253,
#  255,
#  260,
#  261,
#  264,
#  267,
#  269,
#  278,
#  283,
#  295,
#  297,
#  298,
#  299,
#  302,
#  305,
#  306,
#  307,
#  308,
#  311,
#  314,
#  318,
#  319,
#  321,
#  324,
#  327,
#  330,
#  334,
#  335,
#  337,
#  344,
#  348,
#  349,
#  355,
#  356,
#  360,
#  365,
#  367,
#  369,
#  370,
#  372,
#  373,
#  377,
#  379,
#  386,
#  387,
#  392,
#  394,
#  395,
#  397,
#  405,
#  408,
#  416,
#  421,
#  424,
#  431,
#  432,
#  438,
#  439,
#  441,
#  444,
#  445,
#  454,
#  457,
#  463,
#  467,
#  471,
#  472,
#  475,
#  477,
#  483,
#  486,
# ...
